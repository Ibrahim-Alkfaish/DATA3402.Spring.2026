# %% [markdown]
# # Lab 4- Object Oriented Programming
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class Counter:
    def __init__(self, maximum):
        self.value = 0 
        self.maximum = maximum

    def increment(self):
        if self.value >= self.maximum:
            print ("Error: Counter at maximum")
        else:
            self.value += 1
    def reset (self):
        self.value = 0

# %%
c = Counter(3)
c.increment()
c.increment()
c.increment()
c.increment()
print(c.value)
c.reset()
print(c.value)
# Out:
# Error: Counter at maximum
# 3
# 0

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class CounterPrivate:
    def __init__(self, maximum):
        self.__value = 0 
        self.__maximum = maximum

    def increment(self):
        if self.__value >= self.__maximum:
            print ("Error: Counter at maximum")
        else:
            self.__value += 1
    def reset (self):
        self.__value = 0
    def get_value(self):
        return self.__value

    def get_maximum(self):
        return self.__maximum

    def is_at_max(self):
        return self.__value == self.__maximum

# %%
cp = CounterPrivate(2)
cp.increment()
cp.increment()
cp.increment()
print(cp.get_value())
print(cp.is_at_max())
# Out:
# Error: Counter at maximum
# 2
# True

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
import math

class Shape:
    def area(self):
        raise NotImplementedError

    def perimeter(self):
        raise NotImplementedError

    def boundary_points(self):
        raise NotImplementedError

    def contains(self, x, y):
        raise NotImplementedError

    def overlaps(self, other):
        for x, y in self.boundary_points():
            if other.contains(x, y):
                return True
        return False

# %%
class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def boundary_points(self):
        points = []
        for i in range(16):
            t = i / 15
            points.append((self.__x + t*self.__length, self.__y))
        return points

    def contains(self, x, y):
        return (self.__x <= x <= self.__x + self.__length and
                self.__y <= y <= self.__y + self.__width)

    def __repr__(self):
        return f"Rectangle({self.__length},{self.__width},{self.__x},{self.__y})"

# %%
rect = Rectangle(10, 5, 0, 0)

print(f"Testing {rect}:")
print(f"Area: {rect.area()}")
print(f"Perimeter: {rect.perimeter()}")
print(f"Contains (2,2): {rect.contains(2, 2)}")
print(f"Contains (11,5): {rect.contains(11, 5)}")
print(f"Boundary Points (first 3): {rect.boundary_points()[:3]}")
# Out:
# Testing Rectangle(10,5,0,0):
# Area: 50
# Perimeter: 30
# Contains (2,2): True
# Contains (11,5): False
# Boundary Points (first 3): [(0.0, 0), (0.6666666666666666, 0), (1.3333333333333333, 0)]

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius**2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def boundary_points(self):
        points = []
        for i in range(16):
            angle = 2 * math.pi * i / 16
            x = self.__x + self.__radius * math.cos(angle)
            y = self.__y + self.__radius * math.sin(angle)
            points.append((x, y))
        return points

    def contains(self, x, y):
        return (x - self.__x)**2 + (y - self.__y)**2 <= self.__radius**2

    def __repr__(self):
        return f"Circle({self.__radius},{self.__x},{self.__y})"

# %%
circle = Circle(5, 0, 0)

print(f"Testing {circle}:")
print(f"Area: {circle.area()}")
print(f"Perimeter: {circle.perimeter()}")
print(f"Contains (3,4): {circle.contains(3, 4)}")
print(f"Contains (6,0): {circle.contains(6, 0)}")
print(f"Boundary Points (first 3): {circle.boundary_points()[:3]}")
# Out:
# Testing Circle(5,0,0):
# Area: 78.53981633974483
# Perimeter: 31.41592653589793
# Contains (3,4): True
# Contains (6,0): False
# Boundary Points (first 3): [(5.0, 0.0), (4.619397662556434, 1.913417161825449), (3.5355339059327378, 3.5355339059327373)]

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your regtangle and circule classes to inherit from the base class and overload the functions accordingly.

# %%
class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def boundary_points(self):
        points = []
        for i in range(16):
            t = i / 15
            points.append((self.__x + t*self.__length, self.__y))
        return points

    def contains(self, x, y):
        return (self.__x <= x <= self.__x + self.__length and
                self.__y <= y <= self.__y + self.__width)

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_corner(self):
        return (self.__x, self.__y)

# %%
class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius**2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def boundary_points(self):
        points = []
        for i in range(16):
            angle = 2 * math.pi * i / 16
            x = self.__x + self.__radius * math.cos(angle)
            y = self.__y + self.__radius * math.sin(angle)
            points.append((x, y))
        return points

    def contains(self, x, y):
        return (x - self.__x)**2 + (y - self.__y)**2 <= self.__radius**2

    def get_radius(self):
        return self.__radius

    def get_center(self):
        return (self.__x, self.__y)

# %%
r = Rectangle(4, 3, 0, 0)
c = Circle(2, 5, 5)

print("Rectangle Area:", r.area())
print("Rectangle Perimeter:", r.perimeter())
print("Rectangle Contains (2,1):", r.contains(2,1))

print("Circle Area:", c.area())
print("Circle Perimeter:", c.perimeter())
print("Circle Contains (5,5):", c.contains(5,5))
# Out:
# Rectangle Area: 12
# Rectangle Perimeter: 14
# Rectangle Contains (2,1): True
# Circle Area: 12.566370614359172
# Circle Perimeter: 12.566370614359172
# Circle Contains (5,5): True

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
class Triangle(Shape):
    def __init__(self, p1, p2, p3):
        self.__p1 = p1
        self.__p2 = p2
        self.__p3 = p3

    def area(self):
        x1,y1 = self.__p1
        x2,y2 = self.__p2
        x3,y3 = self.__p3
        return abs(x1*(y2-y3)+x2*(y3-y1)+x3*(y1-y2))/2

    def perimeter(self):
        def dist(a,b):
            return math.sqrt((a[0]-b[0])**2 + (a[1]-b[1])**2)
        return dist(self.__p1,self.__p2)+dist(self.__p2,self.__p3)+dist(self.__p3,self.__p1)

    def boundary_points(self):
        return [self.__p1,self.__p2,self.__p3]

    def contains(self, x, y):
        A = self.area()
        t1 = Triangle((x,y),self.__p2,self.__p3).area()
        t2 = Triangle(self.__p1,(x,y),self.__p3).area()
        t3 = Triangle(self.__p1,self.__p2,(x,y)).area()
        return abs(A - (t1+t2+t3)) < 1e-6

    def __repr__(self):
        return f"Triangle({self.__p1},{self.__p2},{self.__p3})"

# %%
r = Rectangle(10, 5, 0, 0)
c = Circle(4, 10, 10)

print("Rectangle area:", r.area())
print("Rectangle perimeter:", r.perimeter())

print("Circle area:", c.area())
print("Circle perimeter:", c.perimeter())
# Out:
# Rectangle area: 50
# Rectangle perimeter: 30
# Circle area: 50.26548245743669
# Circle perimeter: 25.132741228718345

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
def boundary_points(self):
    raise NotImplementedError

# %%
def boundary_points(self):
    points = []
    x0, y0 = self.__x, self.__y
    L, W = self.__length, self.__width

    for i in range(4):
        t = i / 3
        points.append((x0 + t*L, y0))
        points.append((x0 + t*L, y0 + W))
        points.append((x0, y0 + t*W))
        points.append((x0 + L, y0 + t*W))
    return points[:16]

# %%
def boundary_points(self):
    points = []
    x0, y0 = self.__x, self.__y
    L, W = self.__length, self.__width

    for i in range(4):
        t = i / 3
        points.append((x0 + t*L, y0))
        points.append((x0 + t*L, y0 + W))
        points.append((x0, y0 + t*W))
        points.append((x0 + L, y0 + t*W))

    return points[:16]

# %%
def boundary_points(self):
    points = []
    for i in range(16):
        angle = 2 * math.pi * i / 16
        x = self.__x + self.__radius * math.cos(angle)
        y = self.__y + self.__radius * math.sin(angle)
        points.append((x, y))
    return points

# %%
def boundary_points(self):
    return [self.__p1, self.__p2, self.__p3]

# %%
rect = Rectangle(10, 5, 0, 0)
print("Rectangle boundary points:")
rect_points = rect.boundary_points()
print("Count:", len(rect_points))
print("First 3:", rect_points[:3])
print()

circle = Circle(5, 0, 0)
print("Circle boundary points:")
circle_points = circle.boundary_points()
print("Count:", len(circle_points))
print("First 3:", circle_points[:3])
print()

tri = Triangle((0, 0), (5, 0), (2, 4))
print("Triangle boundary points:")
tri_points = tri.boundary_points()
print("Count:", len(tri_points))
print("Points:", tri_points)
# Out:
# Rectangle boundary points:
# Count: 16
# First 3: [(0.0, 0), (0.6666666666666666, 0), (1.3333333333333333, 0)]
#
# Circle boundary points:
# Count: 16
# First 3: [(5.0, 0.0), (4.619397662556434, 1.913417161825449), (3.5355339059327378, 3.5355339059327373)]
#
# Triangle boundary points:
# Count: 3
# Points: [(0, 0), (5, 0), (2, 4)]

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
def contains(self, x, y):
    raise NotImplementedError

# %%
shape = Shape()
try:
    shape.contains(1, 1)
except NotImplementedError:
    print("Base class correctly raises NotImplementedError")
print()

rect = Rectangle(10, 5, 0, 0)
print("Rectangle Tests:")
print("Contains (2,2):", rect.contains(2, 2))
print("Contains (11,5):", rect.contains(11, 5))
print()

circle = Circle(5, 0, 0)
print("Circle Tests:")
print("Contains (3,4):", circle.contains(3, 4))
print("Contains (6,0):", circle.contains(6, 0))

tri = Triangle((0, 0), (5, 0), (2, 4))
print("Triangle Tests:")
print("Contains (2,1):", tri.contains(2, 1))   # Expected: True
print("Contains (4,3):", tri.contains(4, 3))   # Expected: False
print("Contains (0,0):", tri.contains(0, 0))   # Expected: True (vertex)
# Out:
# Base class correctly raises NotImplementedError
#
# Rectangle Tests:
# Contains (2,2): True
# Contains (11,5): False
#
# Circle Tests:
# Contains (3,4): True
# Contains (6,0): False
# Triangle Tests:
# Contains (2,1): True
# Contains (4,3): False
# Contains (0,0): True

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
def overlaps(self, other):
    for x, y in self.boundary_points():
        if other.contains(x, y):
            return True
    for x, y in other.boundary_points():
        if self.contains(x, y):
            return True
    return False

# %%
r1 = Rectangle(10, 5, 0, 0)
r2 = Rectangle(4, 4, 3, 2)
r3 = Rectangle(2, 2, 20, 20)
print("Rectangle overlap tests:")
print("r1 overlaps r2:", r1.overlaps(r2))
print("r1 overlaps r3:", r1.overlaps(r3))
print()

c1 = Circle(5, 0, 0)
c2 = Circle(3, 4, 0)
c3 = Circle(2, 20, 0)
print("Circle overlap tests:")
print("c1 overlaps c2:", c1.overlaps(c2))
print("c1 overlaps c3:", c1.overlaps(c3))
print()

print("Rectangle/Circle overlap:")
print("r1 overlaps c1:", r1.overlaps(c1))
print("r3 overlaps c1:", r3.overlaps(c1))
print()

try:
    t1 = Triangle((0,0), (5,0), (2,4))
    print("Triangle overlap test:")
    print("t1 overlaps r1:", t1.overlaps(r1))
except NameError:
    print("Triangle not defined.")
# Out:
# Rectangle overlap tests:
# r1 overlaps r2: False
# r1 overlaps r3: False
#
# Circle overlap tests:
# c1 overlaps c2: True
# c1 overlaps c3: False
#
# Rectangle/Circle overlap:
# r1 overlaps c1: True
# r3 overlaps c1: False
#
# Triangle overlap test:
# t1 overlaps r1: True

# %% [markdown]
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
class Canvas:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        self.data = [[' '] * width for i in range(height)]

    def set_pixel(self, row, col, char='*'):
        self.data[row][col] = char

    def get_pixel(self, row, col):
        return self.data[row][col]
    
    def clear_canvas(self):
        self.data = [[' '] * self.width for i in range(self.height)]
    
    def v_line(self, x, y, w, **kargs):
        for i in range(x,x+w):
            self.set_pixel(i,y, **kargs)

    def h_line(self, x, y, h, **kargs):
        for i in range(y,y+h):
            self.set_pixel(x,i, **kargs)
            
    def line(self, x1, y1, x2, y2, **kargs):
        slope = (y2-y1) / (x2-x1)
        for y in range(y1,y2):
            x= int(slope * y)
            self.set_pixel(x,y, **kargs)
            
    def display(self):
        print("\n".join(["".join(row) for row in self.data]))

# %%
class Rectangle(Shape):
    def __init__(self, length, width, x, y, char="*"):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y
        self.char = char

    def paint(self, canvas):
        for i in range(int(self.__width)):
            canvas.h_line(int(self.__x + i),
                          int(self.__y),
                          int(self.__length),
                          char=self.char)

# %%
class Circle(Shape):
    def __init__(self, radius, x, y, char="o"):
        self.__radius = radius
        self.__x = x
        self.__y = y
        self.char = char

    def contains(self, x, y):
        return ((x - self.__x) ** 2 +
                (y - self.__y) ** 2) <= self.__radius ** 2

    def area(self):
        import math
        return math.pi * self.__radius ** 2

    def paint(self, canvas):
        for row in range(canvas.height):
            for col in range(canvas.width):
                if self.contains(col, row):
                    canvas.set_pixel(row, col, char=self.char)

# %%
class Triangle(Shape):
    def __init__(self, x1, y1, x2, y2, x3, y3, char="+"):
        self.points = [(x1, y1), (x2, y2), (x3, y3)]
        self.char = char

    def contains(self, x, y):
        def area(x1,y1,x2,y2,x3,y3):
            return abs((x1*(y2-y3) + x2*(y3-y1) + x3*(y1-y2)) / 2.0)

        x1,y1 = self.points[0]
        x2,y2 = self.points[1]
        x3,y3 = self.points[2]

        A  = area(x1,y1,x2,y2,x3,y3)
        A1 = area(x,y,x2,y2,x3,y3)
        A2 = area(x1,y1,x,y,x3,y3)
        A3 = area(x1,y1,x2,y2,x,y)

        return abs(A - (A1 + A2 + A3)) < 0.5

    def paint(self, canvas):
        for row in range(canvas.height):
            for col in range(canvas.width):
                if self.contains(col, row):
                    canvas.set_pixel(row, col, char=self.char)

# %%
def paint(self, canvas):
    for row in range(canvas.height):
        for col in range(canvas.width):
            if self.contains(col, row):
                canvas.set_pixel(row, col, char=self.char)

# %%
class CompoundShape:
    def __init__(self, *shapes):
        self.shapes = list(shapes)

    def add(self, shape):
        self.shapes.append(shape)

    def paint(self, canvas):
        for shape in self.shapes:
            shape.paint(canvas)

# %%
canvas = Canvas(60, 20)

r = Rectangle(10, 5, 2, 2, char="*")
c = Circle(4, 30, 8, char="o")
t = Triangle(10, 15, 20, 5, 30, 15, char="+")

drawing = CompoundShape(r, c, t)
drawing.paint(canvas)
canvas.display()
# Out:
#
#
#   **********
#   **********
#   **********                  o
#   **********        +       ooooo
#   **********       +++     ooooooo
#                   +++++    ooooooo
#                  +++++++  ooooooooo
#                 +++++++++  ooooooo
#                +++++++++++ ooooooo
#               +++++++++++++ ooooo
#              +++++++++++++++  o
#             +++++++++++++++++
#            +++++++++++++++++++
#           +++++++++++++++++++++

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %%
class RasterDrawing:
    def __init__(self, width, height):
        self.canvas = Canvas(width, height)
        self.shapes = []

    def add(self, shape):
        self.shapes.append(shape)

    def remove(self, shape):
        self.shapes.remove(shape)

    def paint(self):
        self.canvas.clear_canvas()
        for shape in self.shapes:
            shape.paint(self.canvas)
        self.canvas.display()

# %%
rd = RasterDrawing(60, 20)

r = Rectangle(10, 5, 2, 2, char="*")
c = Circle(4, 30, 8, char="o")
t = Triangle(10, 15, 20, 5, 30, 15, char="+")

rd.add(r)
rd.add(c)
rd.add(t)

print("First drawing:")
rd.paint()

rd.remove(r)
print("\nAfter removing rectangle:")
rd.paint()
# Out:
# First drawing:
#
#
#   **********
#   **********
#   **********                  o
#   **********        +       ooooo
#   **********       +++     ooooooo
#                   +++++    ooooooo
#                  +++++++  ooooooooo
#                 +++++++++  ooooooo
#                +++++++++++ ooooooo
#               +++++++++++++ ooooo
#              +++++++++++++++  o
#             +++++++++++++++++
#            +++++++++++++++++++
#           +++++++++++++++++++++
#
#
#
#
#
# After removing rectangle:
#
#
#
#
#                               o
#                     +       ooooo
#                    +++     ooooooo
#                   +++++    ooooooo
#                  +++++++  ooooooooo
#                 +++++++++  ooooooo
#                +++++++++++ ooooooo
#               +++++++++++++ ooooo
#              +++++++++++++++  o
#             +++++++++++++++++
#            +++++++++++++++++++
#           +++++++++++++++++++++

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class foo:
    def __init__(self,a,b=None):
        self.a=a
        self.b=b
        
    def __repr__(self):
        return "foo("+repr(self.a)+","+repr(self.b)+")"
    
    def save(self,filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()
        
   
def foo_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
ff=foo(1,"hello")
ff.save("Test.foo")

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[123], line 2
#       1 # Check contents of the saved file
# ----> 2 get_ipython().system('cat Test.foo')
#
# File /lib/python3.13/site-packages/IPython/core/interactiveshell.py:2620, in InteractiveShell.system_piped(self, cmd)
#    2615     raise OSError("Background processes not supported.")
#    2617 # we explicitly do NOT return the subprocess status code, because
#    2618 # a non-None value would trigger :func:`sys.displayhook` calls.
#    2619 # Instead, we store the exit_code in user_ns.
# -> 2620 self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#
# File /lib/python3.13/site-packages/IPython/utils/_process_emscripten.py:10, in system(cmd)
#       9 def system(cmd):
# ---> 10     raise OSError("Not available")
#
# OSError: Not available

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')

# %%
class Rectangle(Shape):
    def __init__(self, length, width, x, y, char="*"):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y
        self.char = char

    def paint(self, canvas):
        for i in range(int(self.__width)):
            canvas.h_line(int(self.__x + i), int(self.__y), int(self.__length), char=self.char)

    def __repr__(self):
        return f'Rectangle({self.__length}, {self.__width}, {self.__x}, {self.__y}, char="{self.char}")'

# %%
class Circle(Shape):
    def __init__(self, radius, x, y, char="o"):
        self.__radius = radius
        self.__x = x
        self.__y = y
        self.char = char

    def contains(self, x, y):
        return ((x - self.__x) ** 2 + (y - self.__y) ** 2) <= self.__radius ** 2

    def paint(self, canvas):
        for row in range(canvas.height):
            for col in range(canvas.width):
                if self.contains(col, row):
                    canvas.set_pixel(row, col, char=self.char)

    def __repr__(self):
        return f'Circle({self.__radius}, {self.__x}, {self.__y}, char="{self.char}")'

# %%
class Triangle(Shape):
    def __init__(self, x1, y1, x2, y2, x3, y3, char="+"):
        self.points = [(x1, y1), (x2, y2), (x3, y3)]
        self.char = char

    def contains(self, x, y):
        def area(x1, y1, x2, y2, x3, y3):
            return abs((x1*(y2-y3) + x2*(y3-y1) + x3*(y1-y2)) / 2.0)

        x1, y1 = self.points[0]
        x2, y2 = self.points[1]
        x3, y3 = self.points[2]

        A = area(x1, y1, x2, y2, x3, y3)
        A1 = area(x, y, x2, y2, x3, y3)
        A2 = area(x1, y1, x, y, x3, y3)
        A3 = area(x1, y1, x2, y2, x, y)

        return abs(A - (A1 + A2 + A3)) < 0.5

    def paint(self, canvas):
        for row in range(canvas.height):
            for col in range(canvas.width):
                if self.contains(col, row):
                    canvas.set_pixel(row, col, char=self.char)

    def __repr__(self):
        x1, y1 = self.points[0]
        x2, y2 = self.points[1]
        x3, y3 = self.points[2]
        return f'Triangle({x1}, {y1}, {x2}, {y2}, {x3}, {y3}, char="{self.char}")'

# %%
def __repr__(self):
    return f"Rectangle({self.width}, {self.height}, {self.x}, {self.y})"
def __repr__(self):
    return f"Circle({self.radius}, {self.x}, {self.y})"
def __repr__(self):
    return f"Triangle({self.p1}, {self.p2}, {self.p3})"

# %%
class RasterDrawing:
    def __init__(self, width, height):
        self.canvas = Canvas(width, height)
        self.shapes = []

    def add(self, shape):
        self.shapes.append(shape)

    def remove(self, shape):
        self.shapes.remove(shape)

    def paint(self):
        self.canvas.clear_canvas()
        for shape in self.shapes:
            shape.paint(self.canvas)
        self.canvas.display()

    def save(self, filename):
        with open(filename, "w") as f:
            for shape in self.shapes:
                f.write(repr(shape) + "\n")

# %%
def load_raster_drawing(filename, width, height):
    rd = RasterDrawing(width, height)
    with open(filename, "r") as f:
        for line in f:
            shape = eval(line.strip())
            rd.add(shape)
    return rd

# %%
rd = RasterDrawing(60, 20)
r = Rectangle(10, 5, 2, 2, char="*")
c = Circle(4, 30, 8, char="o")
t = Triangle(10, 15, 20, 5, 30, 15, char="+")

rd.add(r)
rd.add(c)
rd.add(t)

print("Original Drawing:")
rd.paint()


rd.save("drawing.txt")


rd2 = load_raster_drawing("drawing.txt", 60, 20)

print("\nLoaded Drawing:")
rd2.paint()
# Out:
# Original Drawing:
#
#
#   **********
#   **********
#   **********                  o
#   **********        +       ooooo
#   **********       +++     ooooooo
#                   +++++    ooooooo
#                  +++++++  ooooooooo
#                 +++++++++  ooooooo
#                +++++++++++ ooooooo
#               +++++++++++++ ooooo
#              +++++++++++++++  o
#             +++++++++++++++++
#            +++++++++++++++++++
#           +++++++++++++++++++++
#
#
#
#
#
# Loaded Drawing:
#
#
#   **********
#   **********
#   **********                  o
#   **********        +       ooooo
#   **********       +++     ooooooo
#                   +++++    ooooooo
#                  +++++++  ooooooooo
#                 +++++++++  ooooooo
#                +++++++++++ ooooooo
#               +++++++++++++ ooooo
#              +++++++++++++++  o
#             +++++++++++++++++
#            +++++++++++++++++++
#           +++++++++++++++++++++
